# %% [markdown]
# # Playing Around with Kaggle Spotify Dataset
#
# In this notebook, I play around with the Spotify Dataset on 600k tracks collected by Yamac Eren Ay and hosted on Kaggle here: https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks. In particular, I will be looking at the tracks dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ast import literal_eval

# %%
# Importing the dataset
tracks = pd.read_csv('tracks.csv', parse_dates = ['release_date'], converters={'artists': literal_eval})

# %%
# Keeping only the songs from 2011 onwards
from datetime import datetime
tracks11 = tracks.copy().loc[tracks.release_date >= datetime(2011,1,1)]
tracks11.sort_values(by=['release_date'], inplace=True)
tracks11.head(10)
# Out:
#                             id                   name  popularity  \
# 405273  5vq7gzERQyaD7hXPXojduk               Syahadah          37
# 156524  4uQjPCRQJF2QGTKh2vp45a             Go Go Wine          51
# 156523  380hFJEcn7oP9LM3C5eCMN              Te Quiero          55
# 263499  3bQXzmklJTt1fUPxWfApPg                 Nahy 2          32
# 351157  3m5WQZeRfYjm0KlvXqOOX8            Far l'amore          48
# 351155  1CULOQmwFMft8fhXyg9VTQ  ¿Y Ahora Que Hacemos?          41
# 568436  1F5u1Pgff0uoHOaL099i4b         Przyjdzie czas          31
# 535567  0xvHuwgGbnUhLR6REbipOf                  Sybil          29
# 156529  6ihJx6CCY20eFi5SKsvfqs        Hechizo de Luna          40
# 156512  4qan0qNCFAEu6A2hcwPETn                   Wepa          58
#
#         duration_ms  explicit                         artists  \
# 405273       371733         0                        [Raihan]
# 156524       203461         0                   [Vybz Kartel]
# 156523       278147         0                [Ricardo Arjona]
# 263499       298773         0                [Richard Muller]
# 351157       181693         0  [Bob Sinclar, Raffaella Carrà]
# 351155       184360         0                [Jarabe De Palo]
# 568436       219747         0            [Marek Barbasiewicz]
# 535567       277920         0                       [Traktor]
# 156529       292480         0                   [Latin Sound]
# 156512       242000         0                [Gloria Estefan]
#
#                                                id_artists release_date  \
# 405273                         ['0wWm1rOeaLQ4jkLpn8tmTt']   2011-01-01
# 156524                         ['2NUz5P42WqkxilbI8ocN76']   2011-01-01
# 156523                         ['0h1zs4CTlU9D2QtgPxptUD']   2011-01-01
# 263499                         ['2jldyAonkBDiBG0cNtLgZz']   2011-01-01
# 351157  ['5YFS41yoX0YuFY39fq21oN', '6EVyI0S0b1Ld2nm37m...   2011-01-01
# 351155                         ['5B6H1Dq77AV1LZWrbNsuH5']   2011-01-01
# 568436                         ['7pCkvkjUKty9IfxyTjFNR4']   2011-01-01
# 535567                         ['01czh4LGSprbNEuornDtfu']   2011-01-01
# 156529                         ['5IXSOv8ECLeYpvP65Bk2Wf']   2011-01-01
# 156512                         ['5IFCkqu9J6xdWeYMk5I889']   2011-01-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 405273         0.332   0.119    4   -13.911     1       0.0337        0.8650
# 156524         0.583   0.683    8    -5.450     1       0.1310        0.1820
# 156523         0.717   0.635    2    -5.194     0       0.0298        0.0357
# 263499         0.452   0.386    9    -8.728     1       0.0272        0.0380
# 351157         0.875   0.821    7    -5.029     1       0.2270        0.0424
# 351155         0.822   0.641    1    -6.461     0       0.0293        0.6530
# 568436         0.643   0.705    9    -9.745     0       0.1000        0.3190
# 535567         0.630   0.938    2    -6.222     1       0.0754        0.0285
# 156529         0.791   0.519    8    -8.676     1       0.0468        0.6500
# 156512         0.790   0.749    8    -6.504     1       0.2970        0.0277
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 405273          0.000000    0.1550   0.3740   99.641               4
# 156524          0.000000    0.3850   0.4960   99.805               4
# 156523          0.000008    0.0886   0.6990   92.987               4
# 263499          0.000302    0.1880   0.2270   75.233               4
# 351157          0.000247    0.2910   0.6790  127.995               4
# 351155          0.009360    0.0996   0.4010  114.024               4
# 568436          0.000000    0.0905   0.3740  121.816               4
# 535567          0.000169    0.5120   0.0967  120.991               4
# 156529          0.000249    0.1270   0.6740  160.030               4
# 156512          0.000000    0.1130   0.7000  144.933               4

# %%
# Dropping all duplicate values based on name and artist ids
tracks11.drop_duplicates(subset=['name','id_artists'], keep='first', inplace=True)

# Describing the data
tracks11.info()

# %%
# Getting the main artist's name and also getting the 
tracks11.loc[:,'main_artist'] = tracks11.artists.map(lambda x: x[0])
tracks11['duration_min'] = tracks11['duration_ms'] / 60000

# Getting the dataset head
tracks11.head(10000)

# %%
# Correlation matrix
tracks11.corr()
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000    -0.087383  0.187654      0.185874 -0.085210
# duration_ms        -0.087383     1.000000 -0.053128     -0.093719  0.010715
# explicit            0.187654    -0.053128  1.000000      0.220619  0.024697
# danceability        0.185874    -0.093719  0.220619      1.000000  0.112954
# energy             -0.085210     0.010715  0.024697      0.112954  1.000000
# key                -0.005272     0.011240  0.001424      0.016848  0.039432
# loudness            0.152612    -0.002230  0.052457      0.216085  0.702149
# mode               -0.012191     0.003521 -0.064743     -0.074756 -0.087768
# speechiness         0.060636    -0.072998  0.380810      0.198418  0.070786
# acousticness        0.075982    -0.029087 -0.074656     -0.162079 -0.664034
# instrumentalness   -0.380033     0.064428 -0.125353     -0.172419 -0.044028
# liveness           -0.116607     0.007311 -0.032691     -0.171860  0.182396
# valence             0.064486    -0.122416 -0.013181      0.430494  0.330386
# tempo              -0.033676     0.010189 -0.020120     -0.082643  0.183029
# time_signature      0.012371     0.005370  0.046354      0.183658  0.166912
# duration_min       -0.087383     1.000000 -0.053128     -0.093719  0.010715
#
#                        key  loudness      mode  speechiness  acousticness  \
# popularity       -0.005272  0.152612 -0.012191     0.060636      0.075982
# duration_ms       0.011240 -0.002230  0.003521    -0.072998     -0.029087
# explicit          0.001424  0.052457 -0.064743     0.380810     -0.074656
# danceability      0.016848  0.216085 -0.074756     0.198418     -0.162079
# energy            0.039432  0.702149 -0.087768     0.070786     -0.664034
# key               1.000000  0.027170 -0.146386     0.023593     -0.021609
# loudness          0.027170  1.000000 -0.046562     0.008379     -0.470585
# mode             -0.146386 -0.046562  1.000000    -0.077089      0.080303
# speechiness       0.023593  0.008379 -0.077089     1.000000     -0.048254
# acousticness     -0.021609 -0.470585  0.080303    -0.048254      1.000000
# instrumentalness  0.000187 -0.373114 -0.016225    -0.098879     -0.012642
# liveness         -0.000798  0.048109  0.008792     0.052972     -0.074889
# valence           0.027804  0.305283 -0.020742     0.070541     -0.148802
# tempo             0.007750  0.154062  0.004885     0.014084     -0.144357
# time_signature    0.009503  0.168401 -0.027372     0.037387     -0.142685
# duration_min      0.011240 -0.002230  0.003521    -0.072998     -0.029087
#
#                   instrumentalness  liveness   valence     tempo  \
# popularity               -0.380033 -0.116607  0.064486 -0.033676
# duration_ms               0.064428  0.007311 -0.122416  0.010189
# explicit                 -0.125353 -0.032691 -0.013181 -0.020120
# danceability             -0.172419 -0.171860  0.430494 -0.082643
# energy                   -0.044028  0.182396  0.330386  0.183029
# key                       0.000187 -0.000798  0.027804  0.007750
# loudness                 -0.373114  0.048109  0.305283  0.154062
# mode                     -0.016225  0.008792 -0.020742  0.004885
# speechiness              -0.098879  0.052972  0.070541  0.014084
# acousticness             -0.012642 -0.074889 -0.148802 -0.144357
# instrumentalness          1.000000  0.030996 -0.223525 -0.005289
# liveness                  0.030996  1.000000 -0.007780  0.008750
# valence                  -0.223525 -0.007780  1.000000  0.065827
# tempo                    -0.005289  0.008750  0.065827  1.000000
# time_signature           -0.064296 -0.011788  0.091981  0.050082
# duration_min              0.064428  0.007311 -0.122416  0.010189
#
#                   time_signature  duration_min
# popularity              0.012371     -0.087383
# duration_ms             0.005370      1.000000
# explicit                0.046354     -0.053128
# danceability            0.183658     -0.093719
# energy                  0.166912      0.010715
# key                     0.009503      0.011240
# loudness                0.168401     -0.002230
# mode                   -0.027372      0.003521
# speechiness             0.037387     -0.072998
# acousticness           -0.142685     -0.029087
# instrumentalness       -0.064296      0.064428
# liveness               -0.011788      0.007311
# valence                 0.091981     -0.122416
# tempo                   0.050082      0.010189
# time_signature          1.000000      0.005370
# duration_min            0.005370      1.000000
